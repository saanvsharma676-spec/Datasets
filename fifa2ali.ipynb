# %% [markdown]
# <a href="https://colab.research.google.com/github/saanvsharma676-spec/Datasets/blob/main/fifa2ali.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

data = {
    "HomeGoals": [4, 3, 2, 3, 1],
    "AwayGoals": [1, 0, 1, 1, 0],
    "Attendance": [4444, 18346, 24059, 2549, 23409],
    "Winner": ["France", "USA", "Yugoslavia", "Romania", "Argentina"]
}

k1 = pd.DataFrame(data)

x = k1[["HomeGoals", "AwayGoals", "Attendance"]]
y = k1["Winner"]

model = DecisionTreeClassifier()
model.fit(x, y)

home_goals = int(input("Enter Home Team Goals: "))
away_goals = int(input("Enter Away Team Goals: "))
attendance = int(input("Enter Attendance: "))

new_data = pd.DataFrame({
    "HomeGoals": [home_goals],
    "AwayGoals": [away_goals],
    "Attendance": [attendance]
})

prediction = model.predict(new_data)
print("\nPredicted Winner:", prediction[0])

y_pred = model.predict(x)
accuracy = accuracy_score(y, y_pred)

print(f"\nAccuracy: {accuracy * 100:.2f}%")
# Out:
# Enter Home Team Goals: 4
# Enter Away Team Goals: 1
# Enter Attendance: 4444
#
# Predicted Winner: France
#
# Accuracy: 100.00%
